# %%
from wandern.graph_builder import DAGBuilder

# %%
builder = DAGBuilder(migration_dir="tests/migrations")

# %%
builder.iterate()

# %%
# builder.graph_data

builder.show_graph()

# %%
import networkx as nx

# %%
df = nx.DiGraph()

df.add_edge("a", "b")
df.add_edge("b", "c")
df.add_edge("c", "d")
df.add_edge("c", "e")

nx.draw(df, with_labels=True , pos=nx.spring_layout(df))

# %%
x = df.out_edges("c")

len(x)
# Out:
# 2

# %%
for item in x:
    print(item[0], item[1])
# Out:
# c d
# c e
