# %%
from wandern.graph_builder import DAGBuilder

# %%
builder = DAGBuilder(migration_dir="migrations")

# %%
builder.iterate()
# Out:
# None -> 0001
# 0004 -> 0005
# 0002 -> 0003
# 0003 -> 0004
# 0001 -> 0002
